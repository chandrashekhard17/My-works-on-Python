# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url="https://www.flipkart.com/search?q=" + "tv"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient=urlopen(flipkart_url)

# %%
urlclient

# %%
flipkart_page=urlclient.read()

# %%
flipkart_html=bs(flipkart_page,"html.parser")

# %%
"https://www.flipkart.com/search?q=" + "iffalcon-tcl-79-97-cm-32-inch-hd-ready-led-smart-android-tv-google-assistant/p/itm96e1c0ac31c75?pid=TVSGKNZGHCZRNEDW&lid=LSTTVSGKNZGHCZRNEDWPKDF2X&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=BestsellerId_ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=cc3dac47-42f2-4127-a976-4e5e75b8f16b.TVSGKNZGHCZRNEDW.SEARCH&ppt=sp&ppn=sp&ssid=k1j301j74w0000001706804700736&qH=c9a1fdac6e082dd8"
# Out:
# 'https://www.flipkart.com/search?q=iffalcon-tcl-79-97-cm-32-inch-hd-ready-led-smart-android-tv-google-assistant/p/itm96e1c0ac31c75?pid=TVSGKNZGHCZRNEDW&lid=LSTTVSGKNZGHCZRNEDWPKDF2X&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=BestsellerId_ckf%2Fczl&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=cc3dac47-42f2-4127-a976-4e5e75b8f16b.TVSGKNZGHCZRNEDW.SEARCH&ppt=sp&ppn=sp&ssid=k1j301j74w0000001706804700736&qH=c9a1fdac6e082dd8'

# %%
big_box=flipkart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
len(big_box)
# Out:
# 30

# %%
del big_box[0:3]

# %%
len(big_box)
# Out:
# 27

# %%
productlink="https://www.flipkart.com"+big_box[0].div.div.div.a['href']

# %%
for i in big_box:
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/iffalcon-tcl-u62-139-cm-55-inch-ultra-hd-4k-led-smart-google-tv-dolby-audio-hdr10/p/itmf58a1d1c2ef93?pid=TVSGGJTQPBRFGGZK&lid=LSTTVSGGJTQPBRFGGZKXB2HSI&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=d6da5dbc-357b-48ab-aa54-fe198b229ef3.TVSGGJTQPBRFGGZK.SEARCH&ppt=None&ppn=None&ssid=7mxaxdtw340000001706807130612&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/iffalcon-tcl-u62-108-cm-43-inch-ultra-hd-4k-led-smart-google-tv-dolby-audio-hdr10/p/itm62e38c0ae0e1f?pid=TVSGGJTQPTRDFDGX&lid=LSTTVSGGJTQPTRDFDGXEORYEG&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=d6da5dbc-357b-48ab-aa54-fe198b229ef3.TVSGGJTQPTRDFDGX.SEARCH&ppt=None&ppn=None&ssid=7mxaxdtw340000001706807130612&qH=c9a1fdac6e082dd8
# ...

# %%
productlink
# Out:
# 'https://www.flipkart.com/iffalcon-tcl-u62-139-cm-55-inch-ultra-hd-4k-led-smart-google-tv-dolby-audio-hdr10/p/itmf58a1d1c2ef93?pid=TVSGGJTQPBRFGGZK&lid=LSTTVSGGJTQPBRFGGZKXB2HSI&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=d6da5dbc-357b-48ab-aa54-fe198b229ef3.TVSGGJTQPBRFGGZK.SEARCH&ppt=None&ppn=None&ssid=7mxaxdtw340000001706807130612&qH=c9a1fdac6e082dd8'

# %%
product_req=requests.get(productlink)

# %%
product_req
# Out:
# <Response [200]>

# %%
product_html=bs(product_req.text,'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box=product_html.find_all('div',{'class':'_2c2kV-'})

# %%
comment_box[0].div.div.div.div.div.text
# Out:
# '4.2★'

# %%
len(comment_box)
# Out:
# 3

# %%
for i in comment_box:
    print(i.div.div.div.div.div.text)
# Out:
# 4.2★
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.find_all('p',{'class':'_2-N8zT'})
# Out:
# []
